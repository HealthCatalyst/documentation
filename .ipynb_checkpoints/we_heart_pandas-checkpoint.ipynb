# %% [markdown]
# # We Heart Pandas
#
# Imagine a tool that can read in columnar data, manipulate, transpose, derive, query, describe, analyze, visualize and more. That's python's [pandas library](http://pandas.pydata.org/)! In our [healthcare.ai python package](/py), we use pandas extensively under the hood since it is robust, fast and proven in data science. It seemed apropos to introduce you to it.
#
# This post is also written as a [juptyer notebook](/notebooks/) hosted on our github site. You can follow along there or download it and run it yourself if you prefer.
#
# ## What is Pandas?
#
# Pandas is an amazing data manipulation, cleaning, munging and analysis toolkit [library](http://pandas.pydata.org) for python. It is great for working with structured data from many different sources such as:
#
# - Flat files such as `.xls` Excel spreadsheets or `.csv` files exported from sundry systems
# - Data from SQL queries.
# - Time series data.
#
# ## Pandas Data Structures
#
# Pandas has two main data structures:
#
# - **Series:** a 1 dimensional structure. Think of this as a row in a table or an list in python. Under the covers it is actually a [numpy ndarray](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.html), a highly optimized array of fixed size elements.
#     ```python
#     ['Doe, John', 54, 23.5, 0, 1, 115]
#     ```
#
# - **DataFrame:** a 2 dimensional structure. For those familiar with R dataframes, this is similar. Think of this as a database table, excel spreadsheet or list of lists:
#     ```python
#     [
#         ['Doe, Jane', F, 54, 23.5, 0, 1],
#         ['Doe, John', M, 56, 34.2, 0, 0],
#         ['Doe, Jenny', F, 11, 77.0, 1, 1],
#         ['Doe, Jake', M, 17, 28.3, 0, 1],
#         ...
#     ]
#     ```
#
# ## What can pandas do?
#
# The short answer? A lot. The long answer?
#
# - Robust data IO to/from disparate sources, such as CSV, Excel files, databases, and more.
# - Missing data handling, aka null handling. When you create a dataframe nulls are repesented by `NaN`.
# - Easy creation of new and derived columns, as well as deletion.
# - Grouping functions.
# - Slicing, joining, and sub-setting datasets
# - Reshaping and pivoting
# - Descriptive statistics and summaries of large datasets
# - Visualization with very little effort
#
# ## Examples
#
# Let's load a sample dataset, get some insight into our data with some easy descriptive statistics, manipulate some columns and explore the data. If you don't have any data of your own to play with, you can always find something interesting from the U.S. Government’s [open data initiative](https://www.data.gov/).
#
# I picked up a dataset called [U.S. Chronic Disease Indicators (CDI)
# ](https://catalog.data.gov/dataset/u-s-chronic-disease-indicators-cdi-e50c9).
#
# ### Load the data
#
# First, be sure to import pandas then load the `.csv` file in as a new dataframe:

# %%
import pandas

us_cdi_data = pandas.read_csv('U.S._Chronic_Disease_Indicators__CDI_.csv')
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (7,19,20,21,22,26,27,30,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Initial exploration
#
# After I've loaded some data to explore, I always run a few quick commands to get an initial peek at the data structure. The first is `dataframe.columns`, which returns a list of all the column names (if your source has named columns). When you import data, pandas infers the datatype. Running `dataframe.ftypes`
#
# The next command I run is `dataframe.head(10)` and `dataframe.tail(5)` to get a peek at the first and last **n** number of rows. This is a good sanity check and an easy way to see some of your data.
#
# Run those now:

# %%
us_cdi_data.columns
# Out:
# Index([u'YearStart', u'YearEnd', u'LocationAbbr', u'LocationDesc',
#        u'DataSource', u'Topic', u'Question', u'Response', u'DataValueUnit',
#        u'DataValueTypeID', u'DataValueType', u'DataValue', u'DataValueAlt',
#        u'DataValueFootnoteSymbol', u'DatavalueFootnote', u'LowConfidenceLimit',
#        u'HighConfidenceLimit', u'StratificationCategory1', u'Stratification1',
#        u'StratificationCategory2', u'Stratification2',
#        u'StratificationCategory3', u'Stratification3', u'GeoLocation',
#        u'TopicID', u'QuestionID', u'ResponseID', u'LocationID',
#        u'StratificationCategoryID1', u'StratificationID1',
#        u'StratificationCategoryID2', u'StratificationID2',
#        u'StratificationCategoryID3', u'StratificationID3'],
#       dtype='object')

# %%
us_cdi_data.ftypes
# Out:
# YearStart                      int64:dense
# YearEnd                        int64:dense
# LocationAbbr                  object:dense
# LocationDesc                  object:dense
# DataSource                    object:dense
# Topic                         object:dense
# Question                      object:dense
# Response                      object:dense
# DataValueUnit                 object:dense
# DataValueTypeID               object:dense
# DataValueType                 object:dense
# DataValue                     object:dense
# DataValueAlt                 float64:dense
# DataValueFootnoteSymbol       object:dense
# DatavalueFootnote             object:dense
# LowConfidenceLimit           float64:dense
# HighConfidenceLimit          float64:dense
# StratificationCategory1       object:dense
# Stratification1               object:dense
# StratificationCategory2       object:dense
# Stratification2               object:dense
# StratificationCategory3       object:dense
# Stratification3               object:dense
# GeoLocation                   object:dense
# TopicID                       object:dense
# QuestionID                    object:dense
# ResponseID                    object:dense
# LocationID                    object:dense
# StratificationCategoryID1     object:dense
# StratificationID1             object:dense
# StratificationCategoryID2     object:dense
# StratificationID2             object:dense
# StratificationCategoryID3     object:dense
# StratificationID3             object:dense
# dtype: object

# %%
us_cdi_data.head(10)
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2013     2013           CA            California      YRBSS  Alcohol
# 1       2013     2013           CO              Colorado      YRBSS  Alcohol
# 2       2013     2013           CT           Connecticut      YRBSS  Alcohol
# 3       2013     2013           DC  District of Columbia      YRBSS  Alcohol
# 4       2013     2013           DE              Delaware      YRBSS  Alcohol
# 5       2013     2013           FL               Florida      YRBSS  Alcohol
# 6       2013     2013           GA               Georgia      YRBSS  Alcohol
# 7       2013     2013           GU                  Guam      YRBSS  Alcohol
# 8       2013     2013           HI                Hawaii      YRBSS  Alcohol
# 9       2013     2013           IA                  Iowa      YRBSS  Alcohol
#
#                   Question Response DataValueUnit DataValueTypeID  \
# 0  Alcohol use among youth      NaN             %         CrdPrev
# 1  Alcohol use among youth      NaN             %         CrdPrev
# 2  Alcohol use among youth      NaN             %         CrdPrev
# 3  Alcohol use among youth      NaN             %         CrdPrev
# 4  Alcohol use among youth      NaN             %         CrdPrev
# 5  Alcohol use among youth      NaN             %         CrdPrev
# 6  Alcohol use among youth      NaN             %         CrdPrev
# 7  Alcohol use among youth      NaN             %         CrdPrev
# 8  Alcohol use among youth      NaN             %         CrdPrev
# 9  Alcohol use among youth      NaN             %         CrdPrev
#
#          ...        TopicID QuestionID  ResponseID LocationID  \
# 0        ...            ALC     ALC1_1         NaN          6
# 1        ...            ALC     ALC1_1         NaN          8
# 2        ...            ALC     ALC1_1         NaN          9
# 3        ...            ALC     ALC1_1         NaN         11
# 4        ...            ALC     ALC1_1         NaN         10
# 5        ...            ALC     ALC1_1         NaN         12
# 6        ...            ALC     ALC1_1         NaN         13
# 7        ...            ALC     ALC1_1         NaN         66
# 8        ...            ALC     ALC1_1         NaN         15
# 9        ...            ALC     ALC1_1         NaN         19
#
#   StratificationCategoryID1  StratificationID1  StratificationCategoryID2  \
# 0                   OVERALL                OVR                        NaN
# 1                   OVERALL                OVR                        NaN
# 2                   OVERALL                OVR                        NaN
# 3                   OVERALL                OVR                        NaN
# 4                   OVERALL                OVR                        NaN
# 5                   OVERALL                OVR                        NaN
# 6                   OVERALL                OVR                        NaN
# 7                   OVERALL                OVR                        NaN
# 8                   OVERALL                OVR                        NaN
# 9                   OVERALL                OVR                        NaN
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0               NaN                       NaN               NaN
# 1               NaN                       NaN               NaN
# 2               NaN                       NaN               NaN
# 3               NaN                       NaN               NaN
# 4               NaN                       NaN               NaN
# 5               NaN                       NaN               NaN
# 6               NaN                       NaN               NaN
# 7               NaN                       NaN               NaN
# 8               NaN                       NaN               NaN
# 9               NaN                       NaN               NaN
#
# [10 rows x 34 columns]

# %%
us_cdi_data.tail(5)
# Out:
#         YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 237956       2012     2012           WI       Wisconsin      BRFSS
# 237957       2012     2012           WY         Wyoming      BRFSS
# 237958       2012     2012           GU            Guam      BRFSS
# 237959       2012     2012           PR     Puerto Rico      BRFSS
# 237960       2012     2012           VI  Virgin Islands      BRFSS
#
#                Topic                                           Question  \
# 237956  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237957  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237958  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237959  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237960  Older Adults  Proportion of older adults aged 50-64 years wh...
#
#        Response DataValueUnit DataValueTypeID        ...        TopicID  \
# 237956      NaN             %      AgeAdjPrev        ...            OLD
# 237957      NaN             %      AgeAdjPrev        ...            OLD
# 237958      NaN             %      AgeAdjPrev        ...            OLD
# 237959      NaN             %      AgeAdjPrev        ...            OLD
# 237960      NaN             %      AgeAdjPrev        ...            OLD
#
#        QuestionID  ResponseID LocationID StratificationCategoryID1  \
# 237956     OLD3_2         NaN         55                      RACE
# 237957     OLD3_2         NaN         56                      RACE
# 237958     OLD3_2         NaN         66                      RACE
# 237959     OLD3_2         NaN         72                      RACE
# 237960     OLD3_2         NaN         78                      RACE
#
#         StratificationID1  StratificationCategoryID2 StratificationID2  \
# 237956                MRC                        NaN               NaN
# 237957                MRC                        NaN               NaN
# 237958                MRC                        NaN               NaN
# 237959                MRC                        NaN               NaN
# 237960                MRC                        NaN               NaN
#
#        StratificationCategoryID3 StratificationID3
# 237956                       NaN               NaN
# 237957                       NaN               NaN
# 237958                       NaN               NaN
# 237959                       NaN               NaN
# 237960                       NaN               NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# #### Accessing columns
#
# There are many ways to access a column in your dataframe. Let's say you have a dataframe called `dataframe` that has the following columns:
#
# - Age
# - Gender
# - State
# - Height (inches)
# - Weight (pounds)
# - Encounter Number
#
# While columns can be access directly as an attribute of the dataframe like this `dataframe.Age`, because you may have columns with spaces or other problematic characters, the preferred way to reference a column is with the item bracket notation like this: `dataframe.['Age']`
#
# When you access a column, pandas will return a [pandas Series](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html).
#
# #### Accessing rows
#
# Rows can be accessed individually or sliced by index (row number). Running `dataframe[5]` would return the 6th row as a Series. If you wanted to access the rows between 100 and 200 you would run `dataframe[100:200]`. This functions the same as python's list syntax.
#
# ### Querying Data
#
# Pandas has robust query tools built in. For example, to return a dataframe with just patients over the age of 18 you could run `dataframe[dataframe.Age > 18]`, or select just the patients who live in New Mexico `dataframe[dataframe.State == 'NM']`. Perhaps you yearn for something more complex like selecting all records (rows) who have live in a list of states:
#
# ```python
# target_states = ['NM', 'TX', 'AK']
# dataframe.loc[~dataframe['State'].isin(target_states)]
# ```
#
# Let's pull out all rows where the **State** column is either 'CO', 'CT', or 'CA'

# %%
target_sources = ['CO', 'CA', 'CT']
us_cdi_data.loc[us_cdi_data['LocationAbbr'].isin(target_sources)]
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc      DataSource  \
# 0            2013     2013           CA   California           YRBSS
# 1            2013     2013           CO     Colorado           YRBSS
# 2            2013     2013           CT  Connecticut           YRBSS
# 55           2011     2011           CA   California           PRAMS
# 56           2011     2011           CO     Colorado           PRAMS
# 57           2011     2011           CT  Connecticut           PRAMS
# 110          2012     2012           CA   California  Legal Research
# 111          2012     2012           CO     Colorado  Legal Research
# 112          2012     2012           CT  Connecticut  Legal Research
# 165          2013     2013           CA   California           YRBSS
# 166          2013     2013           CO     Colorado           YRBSS
# 167          2013     2013           CT  Connecticut           YRBSS
# 352          2014     2014           CA   California           BRFSS
# 353          2014     2014           CA   California           BRFSS
# 354          2014     2014           CA   California           BRFSS
# 355          2014     2014           CA   California           BRFSS
# 356          2014     2014           CA   California           BRFSS
# 357          2014     2014           CA   California           BRFSS
# 358          2014     2014           CA   California           BRFSS
# 359          2014     2014           CA   California           BRFSS
# 360          2014     2014           CA   California           BRFSS
# 361          2014     2014           CA   California           BRFSS
# 362          2014     2014           CA   California           BRFSS
# 363          2014     2014           CA   California           BRFSS
# 364          2014     2014           CA   California           BRFSS
# 365          2014     2014           CA   California           BRFSS
# 366          2014     2014           CA   California           BRFSS
# 367          2014     2014           CA   California           BRFSS
# 368          2013     2013           CA   California           BRFSS
# 369          2013     2013           CA   California           BRFSS
# ...           ...      ...          ...          ...             ...
# 237425       2012     2012           CA   California           BRFSS
# 237426       2012     2012           CO     Colorado           BRFSS
# 237427       2012     2012           CT  Connecticut           BRFSS
# 237479       2012     2012           CA   California           BRFSS
# 237480       2012     2012           CO     Colorado           BRFSS
# 237481       2012     2012           CT  Connecticut           BRFSS
# 237533       2012     2012           CA   California           BRFSS
# 237534       2012     2012           CO     Colorado           BRFSS
# 237535       2012     2012           CT  Connecticut           BRFSS
# 237570       2012     2012           CA   California           BRFSS
# 237588       2012     2012           CO     Colorado           BRFSS
# 237589       2012     2012           CT  Connecticut           BRFSS
# 237642       2012     2012           CA   California           BRFSS
# 237643       2012     2012           CO     Colorado           BRFSS
# 237644       2012     2012           CT  Connecticut           BRFSS
# 237696       2012     2012           CA   California           BRFSS
# 237697       2012     2012           CO     Colorado           BRFSS
# 237698       2012     2012           CT  Connecticut           BRFSS
# 237751       2012     2012           CA   California           BRFSS
# 237752       2012     2012           CO     Colorado           BRFSS
# 237753       2012     2012           CT  Connecticut           BRFSS
# 237803       2012     2012           CA   California           BRFSS
# 237804       2012     2012           CO     Colorado           BRFSS
# 237805       2012     2012           CT  Connecticut           BRFSS
# 237857       2012     2012           CA   California           BRFSS
# 237858       2012     2012           CO     Colorado           BRFSS
# 237860       2012     2012           CT  Connecticut           BRFSS
# 237911       2012     2012           CA   California           BRFSS
# 237912       2012     2012           CO     Colorado           BRFSS
# 237913       2012     2012           CT  Connecticut           BRFSS
#
#                Topic                                           Question  \
# 0            Alcohol                            Alcohol use among youth
# 1            Alcohol                            Alcohol use among youth
# 2            Alcohol                            Alcohol use among youth
# 55           Alcohol                       Alcohol use before pregnancy
# 56           Alcohol                       Alcohol use before pregnancy
# 57           Alcohol                       Alcohol use before pregnancy
# 110          Alcohol  Local authority to regulate alcohol outlet den...
# 111          Alcohol  Local authority to regulate alcohol outlet den...
# 112          Alcohol  Local authority to regulate alcohol outlet den...
# 165          Alcohol              Binge drinking prevalence among youth
# 166          Alcohol              Binge drinking prevalence among youth
# 167          Alcohol              Binge drinking prevalence among youth
# 352          Alcohol  Binge drinking prevalence among adults aged >=...
# 353          Alcohol  Binge drinking prevalence among adults aged >=...
# 354          Alcohol  Binge drinking prevalence among adults aged >=...
# 355          Alcohol  Binge drinking prevalence among adults aged >=...
# 356          Alcohol  Binge drinking prevalence among adults aged >=...
# 357          Alcohol  Binge drinking prevalence among adults aged >=...
# 358          Alcohol  Binge drinking prevalence among adults aged >=...
# 359          Alcohol  Binge drinking prevalence among adults aged >=...
# 360          Alcohol  Binge drinking prevalence among adults aged >=...
# 361          Alcohol  Binge drinking prevalence among adults aged >=...
# 362          Alcohol  Binge drinking prevalence among adults aged >=...
# 363          Alcohol  Binge drinking prevalence among adults aged >=...
# 364          Alcohol  Binge drinking prevalence among adults aged >=...
# 365          Alcohol  Binge drinking prevalence among adults aged >=...
# 366          Alcohol  Binge drinking prevalence among adults aged >=...
# 367          Alcohol  Binge drinking prevalence among adults aged >=...
# 368          Alcohol  Binge drinking prevalence among adults aged >=...
# 369          Alcohol  Binge drinking prevalence among adults aged >=...
# ...              ...                                                ...
# 237425  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237426  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237427  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237479  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237480  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237481  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237533  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237534  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237535  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237570  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237588  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237589  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237642  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237643  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237644  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237696  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237697  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237698  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237751  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237752  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237753  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237803  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237804  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237805  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237857  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237858  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237860  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237911  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237912  Older Adults  Proportion of older adults aged 50-64 years wh...
# 237913  Older Adults  Proportion of older adults aged 50-64 years wh...
#
#        Response DataValueUnit DataValueTypeID        ...        TopicID  \
# 0           NaN             %         CrdPrev        ...            ALC
# 1           NaN             %         CrdPrev        ...            ALC
# 2           NaN             %         CrdPrev        ...            ALC
# 55          NaN             %         CrdPrev        ...            ALC
# 56          NaN             %         CrdPrev        ...            ALC
# 57          NaN             %         CrdPrev        ...            ALC
# 110         NaN           NaN     LclCntrlAlc        ...            ALC
# 111         NaN           NaN     LclCntrlAlc        ...            ALC
# 112         NaN           NaN     LclCntrlAlc        ...            ALC
# 165         NaN             %         CrdPrev        ...            ALC
# 166         NaN             %         CrdPrev        ...            ALC
# 167         NaN             %         CrdPrev        ...            ALC
# 352         NaN             %         CrdPrev        ...            ALC
# 353         NaN             %      AgeAdjPrev        ...            ALC
# 354         NaN             %         CrdPrev        ...            ALC
# 355         NaN             %      AgeAdjPrev        ...            ALC
# 356         NaN             %         CrdPrev        ...            ALC
# 357         NaN             %      AgeAdjPrev        ...            ALC
# 358         NaN             %         CrdPrev        ...            ALC
# 359         NaN             %      AgeAdjPrev        ...            ALC
# 360         NaN             %         CrdPrev        ...            ALC
# 361         NaN             %      AgeAdjPrev        ...            ALC
# 362         NaN             %         CrdPrev        ...            ALC
# 363         NaN             %      AgeAdjPrev        ...            ALC
# 364         NaN             %         CrdPrev        ...            ALC
# 365         NaN             %      AgeAdjPrev        ...            ALC
# 366         NaN             %         CrdPrev        ...            ALC
# 367         NaN             %      AgeAdjPrev        ...            ALC
# 368         NaN             %         CrdPrev        ...            ALC
# 369         NaN             %         CrdPrev        ...            ALC
# ...         ...           ...             ...        ...            ...
# 237425      NaN             %         CrdPrev        ...            OLD
# 237426      NaN             %         CrdPrev        ...            OLD
# 237427      NaN             %         CrdPrev        ...            OLD
# 237479      NaN             %      AgeAdjPrev        ...            OLD
# 237480      NaN             %      AgeAdjPrev        ...            OLD
# 237481      NaN             %      AgeAdjPrev        ...            OLD
# 237533      NaN             %         CrdPrev        ...            OLD
# 237534      NaN             %         CrdPrev        ...            OLD
# 237535      NaN             %         CrdPrev        ...            OLD
# 237570      NaN             %      AgeAdjPrev        ...            OLD
# 237588      NaN             %      AgeAdjPrev        ...            OLD
# 237589      NaN             %      AgeAdjPrev        ...            OLD
# 237642      NaN             %         CrdPrev        ...            OLD
# 237643      NaN             %         CrdPrev        ...            OLD
# 237644      NaN             %         CrdPrev        ...            OLD
# 237696      NaN             %      AgeAdjPrev        ...            OLD
# 237697      NaN             %      AgeAdjPrev        ...            OLD
# 237698      NaN             %      AgeAdjPrev        ...            OLD
# 237751      NaN             %         CrdPrev        ...            OLD
# 237752      NaN             %         CrdPrev        ...            OLD
# 237753      NaN             %         CrdPrev        ...            OLD
# 237803      NaN             %      AgeAdjPrev        ...            OLD
# 237804      NaN             %      AgeAdjPrev        ...            OLD
# 237805      NaN             %      AgeAdjPrev        ...            OLD
# 237857      NaN             %         CrdPrev        ...            OLD
# 237858      NaN             %         CrdPrev        ...            OLD
# 237860      NaN             %         CrdPrev        ...            OLD
# 237911      NaN             %      AgeAdjPrev        ...            OLD
# 237912      NaN             %      AgeAdjPrev        ...            OLD
# 237913      NaN             %      AgeAdjPrev        ...            OLD
#
#        QuestionID  ResponseID LocationID StratificationCategoryID1  \
# 0          ALC1_1         NaN          6                   OVERALL
# 1          ALC1_1         NaN          8                   OVERALL
# 2          ALC1_1         NaN          9                   OVERALL
# 55         ALC1_2         NaN          6                   OVERALL
# 56         ALC1_2         NaN          8                   OVERALL
# 57         ALC1_2         NaN          9                   OVERALL
# 110       ALC10_0         NaN          6                   OVERALL
# 111       ALC10_0         NaN          8                   OVERALL
# 112       ALC10_0         NaN          9                   OVERALL
# 165        ALC2_1         NaN          6                   OVERALL
# 166        ALC2_1         NaN          8                   OVERALL
# 167        ALC2_1         NaN          9                   OVERALL
# 352        ALC2_2         NaN          6                   OVERALL
# 353        ALC2_2         NaN          6                   OVERALL
# 354        ALC2_2         NaN          6                    GENDER
# 355        ALC2_2         NaN          6                    GENDER
# 356        ALC2_2         NaN          6                    GENDER
# 357        ALC2_2         NaN          6                    GENDER
# 358        ALC2_2         NaN          6                      RACE
# 359        ALC2_2         NaN          6                      RACE
# 360        ALC2_2         NaN          6                      RACE
# 361        ALC2_2         NaN          6                      RACE
# 362        ALC2_2         NaN          6                      RACE
# 363        ALC2_2         NaN          6                      RACE
# 364        ALC2_2         NaN          6                      RACE
# 365        ALC2_2         NaN          6                      RACE
# 366        ALC2_2         NaN          6                      RACE
# 367        ALC2_2         NaN          6                      RACE
# 368        ALC2_2         NaN          6                    GENDER
# 369        ALC2_2         NaN          6                   OVERALL
# ...           ...         ...        ...                       ...
# 237425     OLD3_2         NaN         06                      RACE
# 237426     OLD3_2         NaN         08                      RACE
# 237427     OLD3_2         NaN         09                      RACE
# 237479     OLD3_2         NaN         06                      RACE
# 237480     OLD3_2         NaN         08                      RACE
# 237481     OLD3_2         NaN         09                      RACE
# 237533     OLD3_2         NaN         06                      RACE
# 237534     OLD3_2         NaN         08                      RACE
# 237535     OLD3_2         NaN         09                      RACE
# 237570     OLD3_2         NaN         06                      RACE
# 237588     OLD3_2         NaN         08                      RACE
# 237589     OLD3_2         NaN         09                      RACE
# 237642     OLD3_2         NaN         06                      RACE
# 237643     OLD3_2         NaN         08                      RACE
# 237644     OLD3_2         NaN         09                      RACE
# 237696     OLD3_2         NaN         06                      RACE
# 237697     OLD3_2         NaN         08                      RACE
# 237698     OLD3_2         NaN         09                      RACE
# 237751     OLD3_2         NaN         06                      RACE
# 237752     OLD3_2         NaN         08                      RACE
# 237753     OLD3_2         NaN         09                      RACE
# 237803     OLD3_2         NaN         06                      RACE
# 237804     OLD3_2         NaN         08                      RACE
# 237805     OLD3_2         NaN         09                      RACE
# 237857     OLD3_2         NaN         06                      RACE
# 237858     OLD3_2         NaN         08                      RACE
# 237860     OLD3_2         NaN         09                      RACE
# 237911     OLD3_2         NaN         06                      RACE
# 237912     OLD3_2         NaN         08                      RACE
# 237913     OLD3_2         NaN         09                      RACE
#
#         StratificationID1  StratificationCategoryID2 StratificationID2  \
# 0                     OVR                        NaN               NaN
# 1                     OVR                        NaN               NaN
# 2                     OVR                        NaN               NaN
# 55                    OVR                        NaN               NaN
# 56                    OVR                        NaN               NaN
# 57                    OVR                        NaN               NaN
# 110                   OVR                        NaN               NaN
# 111                   OVR                        NaN               NaN
# 112                   OVR                        NaN               NaN
# 165                   OVR                        NaN               NaN
# 166                   OVR                        NaN               NaN
# 167                   OVR                        NaN               NaN
# 352                   OVR                        NaN               NaN
# 353                   OVR                        NaN               NaN
# 354                  GENM                        NaN               NaN
# 355                  GENM                        NaN               NaN
# 356                  GENF                        NaN               NaN
# 357                  GENF                        NaN               NaN
# 358                   WHT                        NaN               NaN
# 359                   WHT                        NaN               NaN
# 360                   BLK                        NaN               NaN
# 361                   BLK                        NaN               NaN
# 362                   HIS                        NaN               NaN
# 363                   HIS                        NaN               NaN
# 364                   OTH                        NaN               NaN
# 365                   OTH                        NaN               NaN
# 366                   MRC                        NaN               NaN
# 367                   MRC                        NaN               NaN
# 368                  GENF                        NaN               NaN
# 369                   OVR                        NaN               NaN
# ...                   ...                        ...               ...
# 237425                WHT                        NaN               NaN
# 237426                WHT                        NaN               NaN
# 237427                WHT                        NaN               NaN
# 237479                WHT                        NaN               NaN
# 237480                WHT                        NaN               NaN
# 237481                WHT                        NaN               NaN
# 237533                BLK                        NaN               NaN
# 237534                BLK                        NaN               NaN
# 237535                BLK                        NaN               NaN
# 237570                BLK                        NaN               NaN
# 237588                BLK                        NaN               NaN
# 237589                BLK                        NaN               NaN
# 237642                HIS                        NaN               NaN
# 237643                HIS                        NaN               NaN
# 237644                HIS                        NaN               NaN
# 237696                HIS                        NaN               NaN
# 237697                HIS                        NaN               NaN
# 237698                HIS                        NaN               NaN
# 237751                OTH                        NaN               NaN
# 237752                OTH                        NaN               NaN
# 237753                OTH                        NaN               NaN
# 237803                OTH                        NaN               NaN
# 237804                OTH                        NaN               NaN
# 237805                OTH                        NaN               NaN
# 237857                MRC                        NaN               NaN
# 237858                MRC                        NaN               NaN
# 237860                MRC                        NaN               NaN
# 237911                MRC                        NaN               NaN
# 237912                MRC                        NaN               NaN
# 237913                MRC                        NaN               NaN
#
#        StratificationCategoryID3 StratificationID3
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2                            NaN               NaN
# 55                           NaN               NaN
# 56                           NaN               NaN
# 57                           NaN               NaN
# 110                          NaN               NaN
# 111                          NaN               NaN
# 112                          NaN               NaN
# 165                          NaN               NaN
# 166                          NaN               NaN
# 167                          NaN               NaN
# 352                          NaN               NaN
# 353                          NaN               NaN
# 354                          NaN               NaN
# 355                          NaN               NaN
# 356                          NaN               NaN
# 357                          NaN               NaN
# 358                          NaN               NaN
# 359                          NaN               NaN
# 360                          NaN               NaN
# 361                          NaN               NaN
# 362                          NaN               NaN
# 363                          NaN               NaN
# 364                          NaN               NaN
# 365                          NaN               NaN
# 366                          NaN               NaN
# 367                          NaN               NaN
# 368                          NaN               NaN
# 369                          NaN               NaN
# ...                          ...               ...
# 237425                       NaN               NaN
# 237426                       NaN               NaN
# 237427                       NaN               NaN
# 237479                       NaN               NaN
# 237480                       NaN               NaN
# 237481                       NaN               NaN
# 237533                       NaN               NaN
# 237534                       NaN               NaN
# 237535                       NaN               NaN
# 237570                       NaN               NaN
# 237588                       NaN               NaN
# 237589                       NaN               NaN
# 237642                       NaN               NaN
# 237643                       NaN               NaN
# 237644                       NaN               NaN
# 237696                       NaN               NaN
# 237697                       NaN               NaN
# 237698                       NaN               NaN
# 237751                       NaN               NaN
# 237752                       NaN               NaN
# 237753                       NaN               NaN
# 237803                       NaN               NaN
# 237804                       NaN               NaN
# 237805                       NaN               NaN
# 237857                       NaN               NaN
# 237858                       NaN               NaN
# 237860                       NaN               NaN
# 237911                       NaN               NaN
# 237912                       NaN               NaN
# 237913                       NaN               NaN
#
# [13402 rows x 34 columns]

# %% [markdown]
# ### Sorting
#
# You can sort a dataframe by any column using the `.sort_by` method. If you have a column named 'Age' you could run `dataframe.sort_by('Age')`. For our dataset, let's sort by *YearEnd*:

# %%
us_cdi_data.sort_values(by='YearEnd')
# Out:
#         YearStart  YearEnd LocationAbbr    LocationDesc       DataSource  \
# 207433       2001     2001           CO        Colorado  NVSS, Mortality
# 207454       2001     2001           MT         Montana  NVSS, Mortality
# 207453       2001     2001           MS     Mississippi  NVSS, Mortality
# 207452       2001     2001           MO        Missouri  NVSS, Mortality
# 207451       2001     2001           MN       Minnesota  NVSS, Mortality
# 207385       2001     2001           FL         Florida  NVSS, Mortality
# 207386       2001     2001           GA         Georgia  NVSS, Mortality
# 207387       2001     2001           HI          Hawaii  NVSS, Mortality
# 207388       2001     2001           IA            Iowa  NVSS, Mortality
# 207389       2001     2001           ID           Idaho  NVSS, Mortality
# 207390       2001     2001           IL        Illinois  NVSS, Mortality
# 207391       2001     2001           IN         Indiana  NVSS, Mortality
# 207392       2001     2001           KS          Kansas  NVSS, Mortality
# 207393       2001     2001           KY        Kentucky  NVSS, Mortality
# 207394       2001     2001           LA       Louisiana  NVSS, Mortality
# 207455       2001     2001           NC  North Carolina  NVSS, Mortality
# 207395       2001     2001           MA   Massachusetts  NVSS, Mortality
# 207397       2001     2001           ME           Maine  NVSS, Mortality
# 207398       2001     2001           MI        Michigan  NVSS, Mortality
# 207399       2001     2001           MN       Minnesota  NVSS, Mortality
# 207400       2001     2001           MO        Missouri  NVSS, Mortality
# 207401       2001     2001           MS     Mississippi  NVSS, Mortality
# 207402       2001     2001           MT         Montana  NVSS, Mortality
# 207403       2001     2001           NC  North Carolina  NVSS, Mortality
# 207404       2001     2001           ND    North Dakota  NVSS, Mortality
# 207405       2001     2001           NE        Nebraska  NVSS, Mortality
# 207406       2001     2001           NH   New Hampshire  NVSS, Mortality
# 207407       2001     2001           NJ      New Jersey  NVSS, Mortality
# 207408       2001     2001           NM      New Mexico  NVSS, Mortality
# 207409       2001     2001           NV          Nevada  NVSS, Mortality
# ...           ...      ...          ...             ...              ...
# 174252       2014     2014           TX           Texas            BRFSS
# 104026       2014     2014           NE        Nebraska             NVSS
# 104027       2014     2014           NE        Nebraska             NVSS
# 104028       2014     2014           NE        Nebraska             NVSS
# 47159        2014     2014           MT         Montana            BRFSS
# 47158        2014     2014           MT         Montana            BRFSS
# 47157        2014     2014           MT         Montana            BRFSS
# 174264       2014     2014           TX           Texas            BRFSS
# 174302       2014     2014           UT            Utah            BRFSS
# 174265       2014     2014           TX           Texas            BRFSS
# 174267       2014     2014           TX           Texas            BRFSS
# 103997       2014     2014           ND    North Dakota             NVSS
# 103998       2014     2014           ND    North Dakota             NVSS
# 104011       2014     2014           NE        Nebraska             NVSS
# 104012       2014     2014           NE        Nebraska             NVSS
# 174282       2014     2014           US   United States            BRFSS
# 174281       2014     2014           US   United States            BRFSS
# 174280       2014     2014           US   United States            BRFSS
# 174279       2014     2014           US   United States            BRFSS
# 174278       2014     2014           US   United States            BRFSS
# 174277       2014     2014           US   United States            BRFSS
# 104013       2014     2014           NE        Nebraska             NVSS
# 47164        2014     2014           MT         Montana            BRFSS
# 47163        2014     2014           MT         Montana            BRFSS
# 47162        2014     2014           MT         Montana            BRFSS
# 47161        2014     2014           MT         Montana            BRFSS
# 47160        2014     2014           MT         Montana            BRFSS
# 174268       2014     2014           TX           Texas            BRFSS
# 174266       2014     2014           TX           Texas            BRFSS
# 65843        2014     2014           NY        New York             NVSS
#
#                                         Topic  \
# 207433                 Overarching Conditions
# 207454                 Overarching Conditions
# 207453                 Overarching Conditions
# 207452                 Overarching Conditions
# 207451                 Overarching Conditions
# 207385                 Overarching Conditions
# 207386                 Overarching Conditions
# 207387                 Overarching Conditions
# 207388                 Overarching Conditions
# 207389                 Overarching Conditions
# 207390                 Overarching Conditions
# 207391                 Overarching Conditions
# 207392                 Overarching Conditions
# 207393                 Overarching Conditions
# 207394                 Overarching Conditions
# 207455                 Overarching Conditions
# 207395                 Overarching Conditions
# 207397                 Overarching Conditions
# 207398                 Overarching Conditions
# 207399                 Overarching Conditions
# 207400                 Overarching Conditions
# 207401                 Overarching Conditions
# 207402                 Overarching Conditions
# 207403                 Overarching Conditions
# 207404                 Overarching Conditions
# 207405                 Overarching Conditions
# 207406                 Overarching Conditions
# 207407                 Overarching Conditions
# 207408                 Overarching Conditions
# 207409                 Overarching Conditions
# ...                                       ...
# 174252                               Diabetes
# 104026                 Cardiovascular Disease
# 104027                 Cardiovascular Disease
# 104028                 Cardiovascular Disease
# 47159                                  Cancer
# 47158                                  Cancer
# 47157                                  Cancer
# 174264                               Diabetes
# 174302                               Diabetes
# 174265                               Diabetes
# 174267                               Diabetes
# 103997                 Cardiovascular Disease
# 103998                 Cardiovascular Disease
# 104011                 Cardiovascular Disease
# 104012                 Cardiovascular Disease
# 174282                               Diabetes
# 174281                               Diabetes
# 174280                               Diabetes
# 174279                               Diabetes
# 174278                               Diabetes
# 174277                               Diabetes
# 104013                 Cardiovascular Disease
# 47164                                  Cancer
# 47163                                  Cancer
# 47162                                  Cancer
# 47161                                  Cancer
# 47160                                  Cancer
# 174268                               Diabetes
# 174266                               Diabetes
# 65843   Chronic Obstructive Pulmonary Disease
#
#                                                  Question Response  \
# 207433                    Life expectancy at age 65 years      NaN
# 207454                    Life expectancy at age 65 years      NaN
# 207453                    Life expectancy at age 65 years      NaN
# 207452                    Life expectancy at age 65 years      NaN
# 207451                    Life expectancy at age 65 years      NaN
# 207385                           Life expectancy at birth      NaN
# 207386                           Life expectancy at birth      NaN
# 207387                           Life expectancy at birth      NaN
# 207388                           Life expectancy at birth      NaN
# 207389                           Life expectancy at birth      NaN
# 207390                           Life expectancy at birth      NaN
# 207391                           Life expectancy at birth      NaN
# 207392                           Life expectancy at birth      NaN
# 207393                           Life expectancy at birth      NaN
# 207394                           Life expectancy at birth      NaN
# 207455                    Life expectancy at age 65 years      NaN
# 207395                           Life expectancy at birth      NaN
# 207397                           Life expectancy at birth      NaN
# 207398                           Life expectancy at birth      NaN
# 207399                           Life expectancy at birth      NaN
# 207400                           Life expectancy at birth      NaN
# 207401                           Life expectancy at birth      NaN
# 207402                           Life expectancy at birth      NaN
# 207403                           Life expectancy at birth      NaN
# 207404                           Life expectancy at birth      NaN
# 207405                           Life expectancy at birth      NaN
# 207406                           Life expectancy at birth      NaN
# 207407                           Life expectancy at birth      NaN
# 207408                           Life expectancy at birth      NaN
# 207409                           Life expectancy at birth      NaN
# ...                                                   ...      ...
# 174252  Dilated eye examination among adults aged >= 1...      NaN
# 104026               Mortality from diseases of the heart
# 104027               Mortality from diseases of the heart
# 104028               Mortality from diseases of the heart
# 47159        Mammography use among women aged 50-74 years      NaN
# 47158        Mammography use among women aged 50-74 years      NaN
# 47157        Mammography use among women aged 50-74 years      NaN
# 174264  Dilated eye examination among adults aged >= 1...      NaN
# 174302  Dilated eye examination among adults aged >= 1...      NaN
# 174265  Dilated eye examination among adults aged >= 1...      NaN
# 174267  Dilated eye examination among adults aged >= 1...      NaN
# 103997               Mortality from diseases of the heart
# 103998               Mortality from diseases of the heart
# 104011               Mortality from diseases of the heart
# 104012               Mortality from diseases of the heart
# 174282  Dilated eye examination among adults aged >= 1...      NaN
# 174281  Dilated eye examination among adults aged >= 1...      NaN
# 174280  Dilated eye examination among adults aged >= 1...      NaN
# 174279  Dilated eye examination among adults aged >= 1...      NaN
# 174278  Dilated eye examination among adults aged >= 1...      NaN
# 174277  Dilated eye examination among adults aged >= 1...      NaN
# 104013               Mortality from diseases of the heart
# 47164        Mammography use among women aged 50-74 years      NaN
# 47163        Mammography use among women aged 50-74 years      NaN
# 47162        Mammography use among women aged 50-74 years      NaN
# 47161        Mammography use among women aged 50-74 years      NaN
# 47160        Mammography use among women aged 50-74 years      NaN
# 174268  Dilated eye examination among adults aged >= 1...      NaN
# 174266  Dilated eye examination among adults aged >= 1...      NaN
# 65843   Mortality with chronic obstructive pulmonary d...
#
#             DataValueUnit DataValueTypeID        ...        TopicID  \
# 207433              Years            Nmbr        ...            OVC
# 207454              Years            Nmbr        ...            OVC
# 207453              Years            Nmbr        ...            OVC
# 207452              Years            Nmbr        ...            OVC
# 207451              Years            Nmbr        ...            OVC
# 207385              Years            Nmbr        ...            OVC
# 207386              Years            Nmbr        ...            OVC
# 207387              Years            Nmbr        ...            OVC
# 207388              Years            Nmbr        ...            OVC
# 207389              Years            Nmbr        ...            OVC
# 207390              Years            Nmbr        ...            OVC
# 207391              Years            Nmbr        ...            OVC
# 207392              Years            Nmbr        ...            OVC
# 207393              Years            Nmbr        ...            OVC
# 207394              Years            Nmbr        ...            OVC
# 207455              Years            Nmbr        ...            OVC
# 207395              Years            Nmbr        ...            OVC
# 207397              Years            Nmbr        ...            OVC
# 207398              Years            Nmbr        ...            OVC
# 207399              Years            Nmbr        ...            OVC
# 207400              Years            Nmbr        ...            OVC
# 207401              Years            Nmbr        ...            OVC
# 207402              Years            Nmbr        ...            OVC
# 207403              Years            Nmbr        ...            OVC
# 207404              Years            Nmbr        ...            OVC
# 207405              Years            Nmbr        ...            OVC
# 207406              Years            Nmbr        ...            OVC
# 207407              Years            Nmbr        ...            OVC
# 207408              Years            Nmbr        ...            OVC
# 207409              Years            Nmbr        ...            OVC
# ...                   ...             ...        ...            ...
# 174252                  %         CrdPrev        ...            DIA
# 104026                NaN            Nmbr        ...            CVD
# 104027  cases per 100,000         CrdRate        ...            CVD
# 104028  cases per 100,000      AgeAdjRate        ...            CVD
# 47159                   %         CrdPrev        ...            CAN
# 47158                   %      AgeAdjPrev        ...            CAN
# 47157                   %         CrdPrev        ...            CAN
# 174264                  %      AgeAdjPrev        ...            DIA
# 174302                  %         CrdPrev        ...            DIA
# 174265                  %         CrdPrev        ...            DIA
# 174267                  %         CrdPrev        ...            DIA
# 103997  cases per 100,000         CrdRate        ...            CVD
# 103998  cases per 100,000      AgeAdjRate        ...            CVD
# 104011                NaN            Nmbr        ...            CVD
# 104012  cases per 100,000         CrdRate        ...            CVD
# 174282                  %      AgeAdjPrev        ...            DIA
# 174281                  %         CrdPrev        ...            DIA
# 174280                  %      AgeAdjPrev        ...            DIA
# 174279                  %         CrdPrev        ...            DIA
# 174278                  %      AgeAdjPrev        ...            DIA
# 174277                  %         CrdPrev        ...            DIA
# 104013  cases per 100,000      AgeAdjRate        ...            CVD
# 47164                   %      AgeAdjPrev        ...            CAN
# 47163                   %         CrdPrev        ...            CAN
# 47162                   %      AgeAdjPrev        ...            CAN
# 47161                   %         CrdPrev        ...            CAN
# 47160                   %      AgeAdjPrev        ...            CAN
# 174268                  %      AgeAdjPrev        ...            DIA
# 174266                  %      AgeAdjPrev        ...            DIA
# 65843   cases per 100,000         CrdRate        ...           COPD
#
#        QuestionID  ResponseID LocationID StratificationCategoryID1  \
# 207433     OVC4_2         NaN          8                   OVERALL
# 207454     OVC4_2         NaN         30                   OVERALL
# 207453     OVC4_2         NaN         28                   OVERALL
# 207452     OVC4_2         NaN         29                   OVERALL
# 207451     OVC4_2         NaN         27                   OVERALL
# 207385     OVC4_1         NaN         12                   OVERALL
# 207386     OVC4_1         NaN         13                   OVERALL
# 207387     OVC4_1         NaN         15                   OVERALL
# 207388     OVC4_1         NaN         19                   OVERALL
# 207389     OVC4_1         NaN         16                   OVERALL
# 207390     OVC4_1         NaN         17                   OVERALL
# 207391     OVC4_1         NaN         18                   OVERALL
# 207392     OVC4_1         NaN         20                   OVERALL
# 207393     OVC4_1         NaN         21                   OVERALL
# 207394     OVC4_1         NaN         22                   OVERALL
# 207455     OVC4_2         NaN         37                   OVERALL
# 207395     OVC4_1         NaN         25                   OVERALL
# 207397     OVC4_1         NaN         23                   OVERALL
# 207398     OVC4_1         NaN         26                   OVERALL
# 207399     OVC4_1         NaN         27                   OVERALL
# 207400     OVC4_1         NaN         29                   OVERALL
# 207401     OVC4_1         NaN         28                   OVERALL
# 207402     OVC4_1         NaN         30                   OVERALL
# 207403     OVC4_1         NaN         37                   OVERALL
# 207404     OVC4_1         NaN         38                   OVERALL
# 207405     OVC4_1         NaN         31                   OVERALL
# 207406     OVC4_1         NaN         33                   OVERALL
# 207407     OVC4_1         NaN         34                   OVERALL
# 207408     OVC4_1         NaN         35                   OVERALL
# 207409     OVC4_1         NaN         32                   OVERALL
# ...           ...         ...        ...                       ...
# 174252     DIA7_0         NaN         48                   OVERALL
# 104026     CVD1_2                     31                      RACE
# 104027     CVD1_2                     31                      RACE
# 104028     CVD1_2                     31                      RACE
# 47159      CAN1_0         NaN         30                      RACE
# 47158      CAN1_0         NaN         30                      RACE
# 47157      CAN1_0         NaN         30                      RACE
# 174264     DIA7_0         NaN         48                      RACE
# 174302     DIA7_0         NaN         49                   OVERALL
# 174265     DIA7_0         NaN         48                      RACE
# 174267     DIA7_0         NaN         48                      RACE
# 103997     CVD1_2                     38                      RACE
# 103998     CVD1_2                     38                      RACE
# 104011     CVD1_2                     31                   OVERALL
# 104012     CVD1_2                     31                   OVERALL
# 174282     DIA7_0         NaN         59                    GENDER
# 174281     DIA7_0         NaN         59                    GENDER
# 174280     DIA7_0         NaN         59                    GENDER
# 174279     DIA7_0         NaN         59                    GENDER
# 174278     DIA7_0         NaN         59                   OVERALL
# 174277     DIA7_0         NaN         59                   OVERALL
# 104013     CVD1_2                     31                   OVERALL
# 47164      CAN1_0         NaN         30                      RACE
# 47163      CAN1_0         NaN         30                      RACE
# 47162      CAN1_0         NaN         30                      RACE
# 47161      CAN1_0         NaN         30                      RACE
# 47160      CAN1_0         NaN         30                      RACE
# 174268     DIA7_0         NaN         48                      RACE
# 174266     DIA7_0         NaN         48                      RACE
# 65843     COPD1_1                     36                      RACE
#
#         StratificationID1  StratificationCategoryID2 StratificationID2  \
# 207433                OVR                        NaN               NaN
# 207454                OVR                        NaN               NaN
# 207453                OVR                        NaN               NaN
# 207452                OVR                        NaN               NaN
# 207451                OVR                        NaN               NaN
# 207385                OVR                        NaN               NaN
# 207386                OVR                        NaN               NaN
# 207387                OVR                        NaN               NaN
# 207388                OVR                        NaN               NaN
# 207389                OVR                        NaN               NaN
# 207390                OVR                        NaN               NaN
# 207391                OVR                        NaN               NaN
# 207392                OVR                        NaN               NaN
# 207393                OVR                        NaN               NaN
# 207394                OVR                        NaN               NaN
# 207455                OVR                        NaN               NaN
# 207395                OVR                        NaN               NaN
# 207397                OVR                        NaN               NaN
# 207398                OVR                        NaN               NaN
# 207399                OVR                        NaN               NaN
# 207400                OVR                        NaN               NaN
# 207401                OVR                        NaN               NaN
# 207402                OVR                        NaN               NaN
# 207403                OVR                        NaN               NaN
# 207404                OVR                        NaN               NaN
# 207405                OVR                        NaN               NaN
# 207406                OVR                        NaN               NaN
# 207407                OVR                        NaN               NaN
# 207408                OVR                        NaN               NaN
# 207409                OVR                        NaN               NaN
# ...                   ...                        ...               ...
# 174252                OVR                        NaN               NaN
# 104026               AIAN
# 104027               AIAN
# 104028               AIAN
# 47159                 HIS                        NaN               NaN
# 47158                 BLK                        NaN               NaN
# 47157                 BLK                        NaN               NaN
# 174264                HIS                        NaN               NaN
# 174302                OVR                        NaN               NaN
# 174265                OTH                        NaN               NaN
# 174267                MRC                        NaN               NaN
# 103997                WHT
# 103998                WHT
# 104011                OVR
# 104012                OVR
# 174282               GENF                        NaN               NaN
# 174281               GENF                        NaN               NaN
# 174280               GENM                        NaN               NaN
# 174279               GENM                        NaN               NaN
# 174278                OVR                        NaN               NaN
# 174277                OVR                        NaN               NaN
# 104013                OVR
# 47164                 MRC                        NaN               NaN
# 47163                 MRC                        NaN               NaN
# 47162                 OTH                        NaN               NaN
# 47161                 OTH                        NaN               NaN
# 47160                 HIS                        NaN               NaN
# 174268                MRC                        NaN               NaN
# 174266                OTH                        NaN               NaN
# 65843                 WHT
#
#        StratificationCategoryID3 StratificationID3
# 207433                       NaN               NaN
# 207454                       NaN               NaN
# 207453                       NaN               NaN
# 207452                       NaN               NaN
# 207451                       NaN               NaN
# 207385                       NaN               NaN
# 207386                       NaN               NaN
# 207387                       NaN               NaN
# 207388                       NaN               NaN
# 207389                       NaN               NaN
# 207390                       NaN               NaN
# 207391                       NaN               NaN
# 207392                       NaN               NaN
# 207393                       NaN               NaN
# 207394                       NaN               NaN
# 207455                       NaN               NaN
# 207395                       NaN               NaN
# 207397                       NaN               NaN
# 207398                       NaN               NaN
# 207399                       NaN               NaN
# 207400                       NaN               NaN
# 207401                       NaN               NaN
# 207402                       NaN               NaN
# 207403                       NaN               NaN
# 207404                       NaN               NaN
# 207405                       NaN               NaN
# 207406                       NaN               NaN
# 207407                       NaN               NaN
# 207408                       NaN               NaN
# 207409                       NaN               NaN
# ...                          ...               ...
# 174252                       NaN               NaN
# 104026
# 104027
# 104028
# 47159                        NaN               NaN
# 47158                        NaN               NaN
# 47157                        NaN               NaN
# 174264                       NaN               NaN
# 174302                       NaN               NaN
# 174265                       NaN               NaN
# 174267                       NaN               NaN
# 103997
# 103998
# 104011
# 104012
# 174282                       NaN               NaN
# 174281                       NaN               NaN
# 174280                       NaN               NaN
# 174279                       NaN               NaN
# 174278                       NaN               NaN
# 174277                       NaN               NaN
# 104013
# 47164                        NaN               NaN
# 47163                        NaN               NaN
# 47162                        NaN               NaN
# 47161                        NaN               NaN
# 47160                        NaN               NaN
# 174268                       NaN               NaN
# 174266                       NaN               NaN
# 65843
#
# [237961 rows x 34 columns]

# %% [markdown]
# ### Descriptive Stats
#
# Pandas has some brilliant descriptive statistics tools built in. After you've loaded some data into a dataframe, you can run `dataframe.describe()` to get a quick overview of your data. Do note that it only operates on numerical columns. Run it on our dataset and enjoy the output:

# %%
us_cdi_data.describe()
# Out:
#            YearStart        YearEnd  DataValueAlt  LowConfidenceLimit  \
# count  237961.000000  237961.000000  1.659960e+05       141388.000000
# mean     2012.678254    2012.723833  9.659927e+02           60.392008
# std         1.367197       1.275515  1.884835e+04          102.967598
# min      2001.000000    2001.000000  0.000000e+00            0.000000
# 25%      2012.000000    2012.000000  2.020000e+01           13.000000
# 50%      2013.000000    2013.000000  4.830000e+01           34.100000
# 75%      2014.000000    2014.000000  8.500000e+01           63.600000
# max      2014.000000    2014.000000  4.022808e+06         1293.000000
#
#        HighConfidenceLimit
# count        141388.000000
# mean             74.255692
# std             119.295383
# min               0.490000
# 25%              19.700000
# 50%              48.600000
# 75%              77.100000
# max            2088.000000

# %% [markdown]
# ### Column calculation and feature engineering
#
# Often when you are preparing data for a machine learning model you will want to engineer some features. For example, imagine you had a dataset with patient details and you have weight in pounds and height in inches, but you hypothesise that adding BMI ([body mass index](https://www.nhlbi.nih.gov/health/educational/lose_wt/BMI/bmicalc.htm)) as a feature will help improve your model. Recall that BMI is calculated by dividing a patient's weight in *kg* by the square of their height in *m*. Creating a derived column using pandas is delightfully simple:
#    ```python
#    height_in_meters = (dataframe['Height'] / 25.4 ) / 1000
#    weight_in_kg = dataframe['Weight'] / 2.2
#    dataframe['BMI'] = weight_in_kg / (height_in_meters ** 2)
#    ```
# Using this pattern, columns can be created from arbitrarily complex calculations of other columns (or other data altogether). This makes exploratory feature engineering simple and fast to iterate.
#
# For our dataset, let's make a column that counts the number of years between the start and end dates:

# %%
us_cdi_data['YearsDelta'] = us_cdi_data['YearEnd'] - us_cdi_data['YearStart']

# %% [markdown]
# ## Writing data
#
# Once you've done some manipulation, you may want to write the resulting dataframe out to a file or database.
#
# ### Writing to a file
#
# - Dumping a dataframe out to a file is trivial with `dataframe.to_csv('my_filename.csv')`.
# - Write a dataframe to an excel file is just as easy with `dataframe.to_excel('my_filename.xlsx', sheet_name='My Data'')`
#
# Let's try this with our example:

# %%
us_cdi_data.to_csv('US_CDI_manipulated.csv')

# %% [markdown]
# ### Writing to a database
#
# This process is a little more involved since you need to use [sqlalchemy](http://www.sqlalchemy.org/), a python database library that works with many different databases including SQLite, Postgresql, MySQL, Oracle, MS-SQL, Firebird, Sybase and others.
#
# Your code will look something like this (assuming you have a MSSQL database and a dataframe called `my_dataframe`).
#
# ```python
# import pandas
# from sqlalchemy import create_engine
# engine = create_engine('mssql+pyodbc://user:password@my_data_source_name')
# pandas.to_sql('my_dataframe', engine)
# ```
#
# To see how to connect to other databases, see the [sqlalchemy connection engine docs](http://docs.sqlalchemy.org/en/latest/core/engines.html)
#
# ## How can I learn more?
#
# Pandas is a very robust and mature data tool. While this article has shown you some essential functionality, it is well worth exploring the incredible things that it can do. Take a few minutes and browse through the stellar  [pandas docs](http://pandas.pydata.org/pandas-docs/stable/) to broaden your data horizon.
#
# If that's not enough, or if you want some more concise references, here is a list of great resources if you are looking to learn more.
#
# - Start with this [10 Minutes to pandas](http://pandas.pydata.org/pandas-docs/stable/10min.html) tutorial.
# - When you've mastered that, run through [Essential Basic Functionality](http://pandas.pydata.org/pandas-docs/stable/basics.html).
# - When you are ready to visualize some data, check out the comprehensive [Pandas Visualization docs](http://pandas.pydata.org/pandas-docs/stable/visualization.html).
# - For visual learners like myself, I recommend [Jason Wirth's Visual Pandas talk](https://www.youtube.com/watch?v=9d5-Ti6onew) (26 min youtube video)
# - For a quick reference card, print out Datacamp's [Pandas Basics Cheatsheet](https://www.datacamp.com/community/blog/python-pandas-cheat-sheet) and tape it to your cubicle.
# - For details on connecting to databases, see the [Pandas to_sql docs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_sql.html) and the [sqlalchemy database engine docs](http://docs.sqlalchemy.org/en/latest/core/engines.html).
# - To get started with healthcare machine learning now, see [healthcare.ai](/) for R and Python.
